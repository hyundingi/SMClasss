# %% [markdown]
# [영화순위]
# 1. 2020년 ~ 2023년 영화
# 제목 / 관객수 : 숫자입력 / 날짜
# csv 파일로 저장
# 이미지저장
#
# 2. dataframe 변경
# 관객수 최대값 / 최소값 / 평균 / 최대관객수 5개 / 최소관객수 5개 출력

# %%
import pandas as pd
df = pd.read_csv('movie2020.csv')
df
# Out:
#     2020             남산의 부장들  4750000  2020.01.22.
# 0   2020         다만 악에서 구하소서  4350000  2020.10.28.
# 1   2020                  반도  3810000  2020.07.15.
# 2   2020                 히트맨  2400000  2020.01.22.
# 3   2020                  테넷  2000000  2020.08.26.
# 4   2020                 백두산  8250000  2019.12.19.
# 5   2020               #살아있다  1900000  2020.06.24.
# 6   2020          강철비2: 정상회담  1790000  2020.09.30.
# 7   2020                  담보  1710000  2020.09.29.
# 8   2020              닥터 두리틀  1600000  2020.01.08.
# 9   2020          삼진그룹 영어토익반  1570000  2020.10.21.
# 10  2020              정직한 후보  1530000  2020.02.12.
# 11  2020                  도굴  1540000  2020.11.04.
# 12  2020                 클로젯  1270000  2020.02.05.
# 13  2020              오케이 마담  1220000  2020.08.12.
# 14  2020               해치지않아  1220000  2020.01.15.
# 15  2020         천문: 하늘에 묻는다  2000000  2019.12.26.
# 16  2020                  결백   890000  2020.06.10.
# ...
